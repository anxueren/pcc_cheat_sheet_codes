# %% [markdown]
# ## Reading from a file

# %%
# reading an entire file at once
filename = 'siddhartha.txt'

with open(filename) as f_obj:
    contents = f_obj.read()
    
print(contents)
# Out:
# ï»¿The Project Gutenberg EBook of Siddhartha, by Herman Hesse
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
# Title: Siddhartha
#
# Author: Herman Hesse
#
# Translator: Gunther Olesch, Anke Dreher, Amy Coulter, Stefan Langer and Semyon Chaichenets
#
# Release Date: April 6, 2008 [EBook #2500]
# Last updated: July 2, 2011
# Last updated: January 23, 2013
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK SIDDHARTHA ***
#
#
#
#
# Produced by Michael Pullen,  Chandra Yenco, Isaac Jones
#
#
#
#
#
# SIDDHARTHA
#
# An Indian Tale
#
# by Hermann Hesse
#
#
#
#
#
# FIRST PART
#
# To Romain Rolland, my dear friend
#
#
#
#
# THE SON OF THE BRAHMAN
#
# In the shade of the house, in the sunshine of the riverbank near the
# ...

# %%
# Reading line by line
with open(filename) as f_obj:
    for line in f_obj:
        print(line.rstrip())
# The rstrip() method gets rid of the extra blank lines
# this would result in when printing to the terminal
# Out:
# ï»¿The Project Gutenberg EBook of Siddhartha, by Herman Hesse
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
# Title: Siddhartha
#
# Author: Herman Hesse
#
# Translator: Gunther Olesch, Anke Dreher, Amy Coulter, Stefan Langer and Semyon Chaichenets
#
# Release Date: April 6, 2008 [EBook #2500]
# Last updated: July 2, 2011
# Last updated: January 23, 2013
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK SIDDHARTHA ***
#
#
#
#
# Produced by Michael Pullen,  Chandra Yenco, Isaac Jones
#
#
#
#
#
# SIDDHARTHA
#
# An Indian Tale
#
# by Hermann Hesse
#
#
#
#
#
# FIRST PART
#
# To Romain Rolland, my dear friend
#
#
#
#
# THE SON OF THE BRAHMAN
#
# In the shade of the house, in the sunshine of the riverbank near the
# ...

# %%
# Storing the lines in a list
with open(filename) as f_obj:
    lines = f_obj.readlines()
    
for line in lines:
    print(line.rstrip())
# Out:
# ï»¿The Project Gutenberg EBook of Siddhartha, by Herman Hesse
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
# Title: Siddhartha
#
# Author: Herman Hesse
#
# Translator: Gunther Olesch, Anke Dreher, Amy Coulter, Stefan Langer and Semyon Chaichenets
#
# Release Date: April 6, 2008 [EBook #2500]
# Last updated: July 2, 2011
# Last updated: January 23, 2013
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK SIDDHARTHA ***
#
#
#
#
# Produced by Michael Pullen,  Chandra Yenco, Isaac Jones
#
#
#
#
#
# SIDDHARTHA
#
# An Indian Tale
#
# by Hermann Hesse
#
#
#
#
#
# FIRST PART
#
# To Romain Rolland, my dear friend
#
#
#
#
# THE SON OF THE BRAHMAN
#
# In the shade of the house, in the sunshine of the riverbank near the
# ...

# %% [markdown]
# ## Writing to a file

# %%
# writing to an empty file
filename2 = 'programming.txt'

with open(filename2, 'w') as f:
    f.write("I love programming!")

# %%
# writing multiple lines to an empty file
with open(filename2, 'w') as f:
    f.write("I love programming!\n")
    f.write("I love creating new games.\n")

# %%
# appending to a file
with open(filename2, 'a') as f:
    f.write("I also love working with data.\n")
    f.write("I love making apps as well.\n")

# %% [markdown]
# ## File paths

# %%
# opening a file from a subfolder
f_path = "text_files/alice.txt"

with open(f_path) as f_obj:
    lines = f_obj.readlines()
    
for line in lines:
    print(line.rstrip())
# Out:
# Alice is an American sitcom that aired on CBS from August 31, 1976, to March 19, 1985. The series is based on the 1974 film Alice Doesn't Live Here Anymore.[1] The show stars Linda Lavin in the title role, a widow who moves with her young son to start life over again, and finds a job working at a roadside diner in Phoenix, Arizona. Most of the episodes revolve around events at Mel's Diner, where Alice is employed.

# %%
# opening a file on windows
f_path2 = "D:/GitHub/pcc/text_files/alice.txt"
with open(f_path2) as f_obj:
    lines = f_obj.readlines()

for line in lines:
    print(line.rstrip())
# Out:
# Alice is an American sitcom that aired on CBS from August 31, 1976, to March 19, 1985. The series is based on the 1974 film Alice Doesn't Live Here Anymore.[1] The show stars Linda Lavin in the title role, a widow who moves with her young son to start life over again, and finds a job working at a roadside diner in Phoenix, Arizona. Most of the episodes revolve around events at Mel's Diner, where Alice is employed.

# %%
# opening a file using an absolute path
# f_path3 = "D:/GitHub/pcc/text_files/alice.txt"
# with open(f_path3) as f_obj:
#     lines = f_obj.readlines()

# %% [markdown]
# ## The try-except block

# %%
# handling the ZeroDivisionError exception
try:
    print(5/0)
except ZeroDivisionError:
    print("You can't divide by zero!")
# Out:
# You can't divide by zero!

# %%
# handling the FileNotFoundError exception
f_name = 'siddhartha2.txt'

try:
    with open(f_name) as f_obj:
        lines = f_obj.readlines()
except FileNotFoundError:
    msg = "Can't find file {0}.".format(f_name)
    print(msg)
# Out:
# Can't find file siddhartha2.txt.

# %% [markdown]
# ## The else block
